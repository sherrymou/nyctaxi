# %% [markdown]
# ### NYC Taxi Insights
# This plot is also about the destinations that people who leaves from Cravath, Swaine & Moore go to. During each hour in a day, what are the types of places they go to most frequently? Here are the top 5 categories in each hour.Suprisingly, "health", "doctor" occurs a lot throughout the day (even during the early morning period).
# Here we can probably take some guesses before investigating it deeper:
# * Guess 1: Lawyers from Cravath need medical cares a alot -> they are working under high pressure
# * Guess 2: Lawyers from Cravath need to deal with a lot of injured clients -> their cases are more personal-injury-related.
# * Guess 3: Both Guess 1 and Guess 2
#
#
# From this plot, few more questions rise:
# * Are these places hospitals or drug stores?
# * Are these places "Walk-in" or "by reservations only"?
# * Will lawyers from other law firms also go to "health"-related places a lot?
# * Will people from other industries also go to "health"-related places a lot?
#
# We can make inferences with our dataset.

# %%
import matplotlib.pyplot as plt
import random
plt.figure(figsize=(20,15))
for row in cat.index:
    top = cat.loc[row].sort_values()[-6:-1] # Remove the trivial category
    for point in top.index:
        plt.plot(row, top.loc[point] , "o")
        plt.text(row, top.loc[point]+ random.uniform(-1,1), point)
plt.show()
